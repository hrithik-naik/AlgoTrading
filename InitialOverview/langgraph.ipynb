# %%
import os

def _set_env():
    var = "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"
    if not os.environ.get(var):
        os.environ[var] = var

_set_env()

# %%
from langgraph.graph import StateGraph, START,Graph
import json
from langgraph.graph.message import add_messages

# Initialize the workflow
workflow = Graph()


def input():
    # Load data from the JSON file
    with open("static_data/data.json", "r") as file:
        temp = json.load(file)

    # Initialize a message list to store questions
    all_questions = []
    
    # Extract and print questions from the JSON data
    for category, questions in temp.items():
        print(f"Category: {category}")
        for question_dict in questions:
            # Extract the 'question' value and add it to the message list
            question = question_dict['question']
            print(f"- {question}")
            all_questions.append(question)
            


  


input()
workflow.add_node("Input",input)
# Out:
# Category: Industry Demand
# - What are the growth trends in the Indian software development market and how are these trends likely to impact Aris International Ltd's revenue?
# - Who are the main competitors of Aris International Ltd in the software development, real estate, and auto parts & equipment industries?
# - How is the demand for import & export of merchandise, software development, real estate, and auto parts & equipment impacting Aris International Ltd's valuation?
# Category: Market Size
# - How large is the market for software development services in India and how does Aris International Ltd's market share compare to its competitors?
# - What is the total addressable market for Aris International Ltd's combined operations across software development, real estate, and auto parts & equipment?
# - What are the key factors that will determine the future growth potential of Aris International Ltd's markets?
# Category: Stage of Development
# ...

# %%
#Scraping whole website based on the company CODE 
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.action_chains import ActionChains
import time


driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))
actions = ActionChains(driver)
def summarizer(question):
    final=""
    driver.maximize_window()
    driver.get("https://www.google.com/")
    try:
        inputfield= driver.find_element(By.XPATH, "/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea")
        inputfield.send_keys(question, Keys.RETURN)
        firstlink=driver.find_element(By.XPATH,"/html/body/div[3]/div/div[13]/div/div[2]/div[2]/div/div/div[1]/div/div/div/div[1]/div/div")
        firstlink.click()
        fullwebsiteScrape=driver.find_element(By.XPATH,"/html/body")
        final=fullwebsiteScrape.text
        
        
        
        
        
        
    except:
        final="the text was not scraped"
        print("failed")
    print(final)
    summaryofthewebscraped(question,final)



    return final

    

currentsummary=summarizer("What is the anticipated impact of global economic uncertainties on the demand for Aris International Ltd's products and services?")
driver.close()
# Out:
# Accessibility links
# Skip to main content
# Accessibility help
# Accessibility feedback
# What is the anticipated impact of global economic uncertainties on the demand for Aris International Ltd's products and services?
# Sign in
# Filters and topics
# All
# News
# Images
# Shopping
# Videos
# Web
# Books
# More
# Tools
# Search Results
#
# How High Economic Uncertainty May Threaten Global ...
# International Monetary Fund
# https://www.imf.org › Blogs › Articles › 2024/10/15
# 15 Oct 2024 — Unknowns raise risk of financial market volatility and a sharp decline in economic growth.
# Missing: Aris Ltd's products services?
# People also ask
# What impact has international business had on the global economy?
#
# What is the effect of economic uncertainty on a business?
#
# What are the effects of global uncertainty on the global economy and large developed and developing economies?
#
#
#
# What are the effects of global economic integration to the global economy?
#
# Feedback
#
# ...

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyD_7bMGuu883w5-Gdp00JDtHKl8Jd_VZs4")

# Create the model
generation_config = {
  "temperature": 2,
  "top_p": 0.95,
  "top_k": 64,
  "max_output_tokens": 8192,
  "response_mime_type": "text/plain",
}
# by specifing application/json it gives good output


model = genai.GenerativeModel(
  model_name="gemini-1.5-flash",
  generation_config=generation_config,
)

chat_session = model.start_chat(
  history=[
  ]
)
def summaryofthewebscraped(question,scraped):
    base_prompt=("Your job is to summarize a webscraped page based on the question the summary shouldnt cross 100 words "
                 f"The question${question}"
                 f"The webscraped Website "
                 f"${scraped}")
    response = chat_session.send_message(base_prompt)
    print(response.text)
